# %% [markdown]
# ## HOTOSM Road Classification
# In this notebook, we will try to classify the road conditions as paved and unpaved using the street level images collected from the
# Mapillary project.
#
# For the classification, we will train a convolutional neural network architecture called MobileNet which is a light weight model, usually deployed in edge devices.

# %%
import os
import glob
import cv2
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import image as mpimg
from PIL import Image
from sklearn.model_selection import train_test_split
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import precision_score, recall_score, f1_score
from sklearn.metrics import classification_report
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPool2D, Dropout, Input, GlobalAveragePooling2D

# %% [markdown]
# ### Exploratory data analysis
# Let's take a look at the data first. The data for this road classification exist in 2 folders, paved and unpaved.

# %%
! ls /Users/savin/Omdena-Projects/HOTOSM/data/Roads/Paved/ | head -10
# Out:
# 0.jpg
# 1.jpg
# 10.jpg
# 11.jpg
# 12.jpg
# 13.jpg
# 14.jpg
# 16.jpg
# 17.jpg
# 18.jpg

# %% [markdown]
# Now let's collect the filepath of files in each folder and their labels to a pandas dataframe.

# %%
# Directory containing the data
data_path = "/Users/savin/Omdena-Projects/HOTOSM/data/Roads/"

# Listing number of image files in each folder list
folds = [item for item in  os.listdir(data_path) if os.path.isdir(data_path+item)] # image directories
file_len = np.zeros(len(folds)) # Number of files in each folder

# Collecting the filepath of each files and their associated folder labeling
# Will be used for train and test split of the data
image_filepath = []
labels = []

for i,fold in enumerate(sorted(folds)):
    files = glob.glob(data_path+fold+"/*.jpg")
    nfiles = len(files)
    file_len[i] = nfiles
    for filepath in files:
        image_filepath.append(filepath)
        labels.append(i)

print(f"Number of files in {folds[0]} folder: {file_len[0]: 0.0f}")
print(f"Number of files in {folds[1]} folder: {file_len[1]: 0.0f}")

# saving the information into a pandas dictionary
df = pd.DataFrame.from_dict({'X_path':image_filepath, 'Y':labels})
df = df.sample(frac=1) # shuffling the data

fig, ax = plt.subplots(figsize=(10,8))

ax.bar(sorted(folds), file_len)
ax.set_ylabel("No. of files")
ax.tick_params(axis='x', labelrotation = 45)
plt.show()
# Out:
# Number of files in Unpaved folder:  423
# Number of files in Paved folder:  288

# %% [markdown]
# Now Let's read the images in these folders into a numpy array which we can use for modelling. But before that we need to make sure if all of these images have the same dimensions.
#
# #### Data Splitting to train and test
# Before loading the data, let's split the data into train and test. Since we have a limited amount of images, we are splitting into cross validation datasets.

# %%
df.head(10)
# Out:
#                                                 X_path  Y
# 79   /Users/savin/Omdena-Projects/HOTOSM/data/Roads...  0
# 66   /Users/savin/Omdena-Projects/HOTOSM/data/Roads...  0
# 615  /Users/savin/Omdena-Projects/HOTOSM/data/Roads...  1
# 619  /Users/savin/Omdena-Projects/HOTOSM/data/Roads...  1
# 641  /Users/savin/Omdena-Projects/HOTOSM/data/Roads...  1
# 526  /Users/savin/Omdena-Projects/HOTOSM/data/Roads...  1
# 584  /Users/savin/Omdena-Projects/HOTOSM/data/Roads...  1
# 476  /Users/savin/Omdena-Projects/HOTOSM/data/Roads...  1
# 645  /Users/savin/Omdena-Projects/HOTOSM/data/Roads...  1
# 114  /Users/savin/Omdena-Projects/HOTOSM/data/Roads...  0

# %%
# stratisfied splitting the data into 80% train and 20 % test to ensure that the test data contains 
# more or less equal distributions of different classes
X_train_path, X_test_path, Y_train, Y_test = train_test_split(df['X_path'], df['Y'], test_size=0.2, random_state=42, stratify = df['Y'])
print(Y_train.shape, Y_test.shape)
# Out:
# (568,) (143,)

# %% [markdown]
# ### Preprocessing
# We will try to get the metdata of the images to understand the dimension of the images. If they are different we need to resize them before feeding into CNN algorithms.

# %%
# Let's try to get the metadata information from the image files without reading them in memory using the Pillow package

h = [] # height
w = [] # width

for i, filepath in enumerate(df['X_path']):
    img = Image.open(filepath)
    width, height = img.size
    h.append(height)
    w.append(width)

print(np.unique(np.array(h)))
print(np.unique(np.array(w)))
# Out:
# [ 648  659  672  782 1067 1290 1575 1611 1641 1648 1673 1732 1776 1864
#  1914 1915 1940 2028 2292 2433 2448 3000 3008 3024]
# [1152 1158 1169 1179 1183 1270 1279 1428 1739 2060 2250 2521 2594 2682
#  2704 2711 2761 2922 2984 3035 3090 3264 3357 3529 4000 4032 5344]

# %% [markdown]
# Interestingly, the dimensions of the images varies a lots as they are collected through different sources. Let's resize all the images to (224 by 160), which are the acceptable image dimensions of the DL models.

# %%
# Let's read the image file into a numpy array
#dimensions of the resized image
width, height = [224, 160]

def load_data(df):
    """
    Returns the array with loaded images from
    the image files
    args:
    df : dataframe containing the filepaths
    """
    samp = df.shape[0]
    #print(samp)
    data = np.zeros((samp, height, width, 3), dtype = np.float32) # Each image with width, height and 3 RGB channels
    for i in range(samp):
        filename = df.iloc[i]
        
        # Load the image
        img = cv2.imread(filename)
        
        if img is not None:
            img_resized = cv2.resize(img, (width, height), interpolation=cv2.INTER_AREA) # resize the images
            data[i,:,:,:] = img_resized/255 # Normalize the pixel values
        else:
            print("Image cannot be opened or read")

    return data

# %%
# Get the train data and test data

X_train = load_data(X_train_path)
X_test = load_data(X_test_path)

print(f" X train shape : {X_train.shape}")
print(f"X test shape : {X_test.shape}")
# Out:
#  X train shape : (568, 160, 224, 3)
# X test shape : (143, 160, 224, 3)

# %%
# Let's plot a random image files to see the collected data
fig, axs = plt.subplots(4, 4, figsize=(12,10), tight_layout = True)
axs = axs.flatten()
for i in range(len(axs)):
    axs[i].imshow(X_train[i, :, :, :])
    axs[i].set_title(f"Cat:{Y_train.iloc[i]}")
    axs[i].axis("off")
plt.show()

# %% [markdown]
# The class: 0  is paved and class:1 is unpaved.

# %% [markdown]
# ## Modeling of data
# For modeling, we will try the MobileNetV2 model. This model utilizes a combination of the bottleneck units which uses a combination of expansion, depthwise seperated convolution and projection) along with residual units to improve the model performance.

# %%
# import the tensorflow model here
from tensorflow.keras.applications import MobileNetV2

# Let's create a function for the model

def call_mobilenet(input_shape):
    
    # Calling the Resnet model
    mob_model = MobileNetV2(
    include_top=False, # remove the top layer or the classification layer (1000 classes from imagenet training)
    weights="imagenet", # utilize imagenet weights
    input_tensor=None,
    input_shape=input_shape, # time steps axis not needed here
    pooling=None)  # no pooling mentioned

    #print a summary of the base model
    mob_model.summary()

    nb_layers = len(mob_model.layers)
    print(f"No. of MobileNetV2 model layers: {nb_layers}")

    # Freeze the base model as we wan to use the pretrained weights
    mob_model.trainable = False

    return mob_model

def create_model(input_shape, nclass):

    """
    Function returns the model output
    Args:
    input shape: shape of the input train/test data (excluding the batch size)
    nclass: number of output classes
    """
    # start the model
    model = Sequential()

    # defining the input layer
    model.add(Input(shape=input_shape))

    # resnet layer for feature extraction
    model.add(call_mobilenet(input_shape)) # calling the mobilenet function here

    # adding a 2D global average to reduce the size and summarize the info in each channel
    model.add(GlobalAveragePooling2D())
    
    # flattening  not needed anymore with the global averaging
    
    # Drop out regularization
    model.add(Dropout(0.2))
              
    # fully connected layers
    model.add(Dense(256, activation='relu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(16, activation='relu'))
    
    # Final output layer, Binary classification
    model.add(Dense(1, activation='sigmoid'))

    return model

# %%
nclass = len(np.unique(Y_train))
input_shape = X_train.shape[1:] 
print(input_shape, nclass)
# Out:
# (160, 224, 3) 2

# %%
# Create the model
mob_netv2 = create_model(input_shape, nclass)
# This will print out the basic MobileNetV2 architecture
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Model: "mobilenetv2_1.00_224"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_10 (InputLayer)          [(None, 160, 224, 3  0           []
#                                 )]
#
#  Conv1 (Conv2D)                 (None, 80, 112, 32)  864         ['input_10[0][0]']
#
#  bn_Conv1 (BatchNormalization)  (None, 80, 112, 32)  128         ['Conv1[0][0]']
#
#  Conv1_relu (ReLU)              (None, 80, 112, 32)  0           ['bn_Conv1[0][0]']
#
#  expanded_conv_depthwise (Depth  (None, 80, 112, 32)  288        ['Conv1_relu[0][0]']
#  wiseConv2D)
#
#  expanded_conv_depthwise_BN (Ba  (None, 80, 112, 32)  128        ['expanded_conv_depthwise[0][0]']
#  tchNormalization)
#
#  expanded_conv_depthwise_relu (  (None, 80, 112, 32)  0          ['expanded_conv_depthwise_BN[0][0
#  ReLU)                                                           ]']
#
#  expanded_conv_project (Conv2D)  (None, 80, 112, 16)  512        ['expanded_conv_depthwise_relu[0]
#                                                                  [0]']
#
#  expanded_conv_project_BN (Batc  (None, 80, 112, 16)  64         ['expanded_conv_project[0][0]']
#  hNormalization)
#
#  block_1_expand (Conv2D)        (None, 80, 112, 96)  1536        ['expanded_conv_project_BN[0][0]'
#                                                                  ]
#
#  block_1_expand_BN (BatchNormal  (None, 80, 112, 96)  384        ['block_1_expand[0][0]']
#  ization)
#
#  block_1_expand_relu (ReLU)     (None, 80, 112, 96)  0           ['block_1_expand_BN[0][0]']
#
#  block_1_pad (ZeroPadding2D)    (None, 81, 113, 96)  0           ['block_1_expand_relu[0][0]']
#
#  block_1_depthwise (DepthwiseCo  (None, 40, 56, 96)  864         ['block_1_pad[0][0]']
#  nv2D)
#
#  block_1_depthwise_BN (BatchNor  (None, 40, 56, 96)  384         ['block_1_depthwise[0][0]']
#  malization)
#
#  block_1_depthwise_relu (ReLU)  (None, 40, 56, 96)   0           ['block_1_depthwise_BN[0][0]']
#
#  block_1_project (Conv2D)       (None, 40, 56, 24)   2304        ['block_1_depthwise_relu[0][0]']
#
#  block_1_project_BN (BatchNorma  (None, 40, 56, 24)  96          ['block_1_project[0][0]']
#  lization)
#
#  block_2_expand (Conv2D)        (None, 40, 56, 144)  3456        ['block_1_project_BN[0][0]']
#
#  block_2_expand_BN (BatchNormal  (None, 40, 56, 144)  576        ['block_2_expand[0][0]']
#  ization)
#
#  block_2_expand_relu (ReLU)     (None, 40, 56, 144)  0           ['block_2_expand_BN[0][0]']
#
#  block_2_depthwise (DepthwiseCo  (None, 40, 56, 144)  1296       ['block_2_expand_relu[0][0]']
#  nv2D)
#
#  block_2_depthwise_BN (BatchNor  (None, 40, 56, 144)  576        ['block_2_depthwise[0][0]']
#  malization)
#
#  block_2_depthwise_relu (ReLU)  (None, 40, 56, 144)  0           ['block_2_depthwise_BN[0][0]']
#
#  block_2_project (Conv2D)       (None, 40, 56, 24)   3456        ['block_2_depthwise_relu[0][0]']
#
#  block_2_project_BN (BatchNorma  (None, 40, 56, 24)  96          ['block_2_project[0][0]']
#  lization)
#
#  block_2_add (Add)              (None, 40, 56, 24)   0           ['block_1_project_BN[0][0]',
#                                                                   'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)        (None, 40, 56, 144)  3456        ['block_2_add[0][0]']
#
#  block_3_expand_BN (BatchNormal  (None, 40, 56, 144)  576        ['block_3_expand[0][0]']
#  ization)
#
#  block_3_expand_relu (ReLU)     (None, 40, 56, 144)  0           ['block_3_expand_BN[0][0]']
#
#  block_3_pad (ZeroPadding2D)    (None, 41, 57, 144)  0           ['block_3_expand_relu[0][0]']
#
#  block_3_depthwise (DepthwiseCo  (None, 20, 28, 144)  1296       ['block_3_pad[0][0]']
#  nv2D)
#
#  block_3_depthwise_BN (BatchNor  (None, 20, 28, 144)  576        ['block_3_depthwise[0][0]']
#  malization)
#
#  block_3_depthwise_relu (ReLU)  (None, 20, 28, 144)  0           ['block_3_depthwise_BN[0][0]']
#
#  block_3_project (Conv2D)       (None, 20, 28, 32)   4608        ['block_3_depthwise_relu[0][0]']
#
#  block_3_project_BN (BatchNorma  (None, 20, 28, 32)  128         ['block_3_project[0][0]']
#  lization)
#
#  block_4_expand (Conv2D)        (None, 20, 28, 192)  6144        ['block_3_project_BN[0][0]']
#
#  block_4_expand_BN (BatchNormal  (None, 20, 28, 192)  768        ['block_4_expand[0][0]']
#  ization)
#
#  block_4_expand_relu (ReLU)     (None, 20, 28, 192)  0           ['block_4_expand_BN[0][0]']
#
#  block_4_depthwise (DepthwiseCo  (None, 20, 28, 192)  1728       ['block_4_expand_relu[0][0]']
#  nv2D)
#
#  block_4_depthwise_BN (BatchNor  (None, 20, 28, 192)  768        ['block_4_depthwise[0][0]']
#  malization)
#
#  block_4_depthwise_relu (ReLU)  (None, 20, 28, 192)  0           ['block_4_depthwise_BN[0][0]']
#
#  block_4_project (Conv2D)       (None, 20, 28, 32)   6144        ['block_4_depthwise_relu[0][0]']
#
#  block_4_project_BN (BatchNorma  (None, 20, 28, 32)  128         ['block_4_project[0][0]']
#  lization)
#
#  block_4_add (Add)              (None, 20, 28, 32)   0           ['block_3_project_BN[0][0]',
#                                                                   'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)        (None, 20, 28, 192)  6144        ['block_4_add[0][0]']
#
#  block_5_expand_BN (BatchNormal  (None, 20, 28, 192)  768        ['block_5_expand[0][0]']
#  ization)
#
#  block_5_expand_relu (ReLU)     (None, 20, 28, 192)  0           ['block_5_expand_BN[0][0]']
#
#  block_5_depthwise (DepthwiseCo  (None, 20, 28, 192)  1728       ['block_5_expand_relu[0][0]']
#  nv2D)
#
#  block_5_depthwise_BN (BatchNor  (None, 20, 28, 192)  768        ['block_5_depthwise[0][0]']
#  malization)
#
#  block_5_depthwise_relu (ReLU)  (None, 20, 28, 192)  0           ['block_5_depthwise_BN[0][0]']
#
#  block_5_project (Conv2D)       (None, 20, 28, 32)   6144        ['block_5_depthwise_relu[0][0]']
#
#  block_5_project_BN (BatchNorma  (None, 20, 28, 32)  128         ['block_5_project[0][0]']
#  lization)
#
#  block_5_add (Add)              (None, 20, 28, 32)   0           ['block_4_add[0][0]',
#                                                                   'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)        (None, 20, 28, 192)  6144        ['block_5_add[0][0]']
#
#  block_6_expand_BN (BatchNormal  (None, 20, 28, 192)  768        ['block_6_expand[0][0]']
#  ization)
#
#  block_6_expand_relu (ReLU)     (None, 20, 28, 192)  0           ['block_6_expand_BN[0][0]']
#
#  block_6_pad (ZeroPadding2D)    (None, 21, 29, 192)  0           ['block_6_expand_relu[0][0]']
#
#  block_6_depthwise (DepthwiseCo  (None, 10, 14, 192)  1728       ['block_6_pad[0][0]']
#  nv2D)
#
#  block_6_depthwise_BN (BatchNor  (None, 10, 14, 192)  768        ['block_6_depthwise[0][0]']
#  malization)
#
#  block_6_depthwise_relu (ReLU)  (None, 10, 14, 192)  0           ['block_6_depthwise_BN[0][0]']
#
#  block_6_project (Conv2D)       (None, 10, 14, 64)   12288       ['block_6_depthwise_relu[0][0]']
#
#  block_6_project_BN (BatchNorma  (None, 10, 14, 64)  256         ['block_6_project[0][0]']
#  lization)
#
#  block_7_expand (Conv2D)        (None, 10, 14, 384)  24576       ['block_6_project_BN[0][0]']
#
#  block_7_expand_BN (BatchNormal  (None, 10, 14, 384)  1536       ['block_7_expand[0][0]']
#  ization)
#
#  block_7_expand_relu (ReLU)     (None, 10, 14, 384)  0           ['block_7_expand_BN[0][0]']
#
#  block_7_depthwise (DepthwiseCo  (None, 10, 14, 384)  3456       ['block_7_expand_relu[0][0]']
#  nv2D)
#
#  block_7_depthwise_BN (BatchNor  (None, 10, 14, 384)  1536       ['block_7_depthwise[0][0]']
#  malization)
#
#  block_7_depthwise_relu (ReLU)  (None, 10, 14, 384)  0           ['block_7_depthwise_BN[0][0]']
#
#  block_7_project (Conv2D)       (None, 10, 14, 64)   24576       ['block_7_depthwise_relu[0][0]']
#
#  block_7_project_BN (BatchNorma  (None, 10, 14, 64)  256         ['block_7_project[0][0]']
#  lization)
#
#  block_7_add (Add)              (None, 10, 14, 64)   0           ['block_6_project_BN[0][0]',
#                                                                   'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)        (None, 10, 14, 384)  24576       ['block_7_add[0][0]']
#
#  block_8_expand_BN (BatchNormal  (None, 10, 14, 384)  1536       ['block_8_expand[0][0]']
#  ization)
#
#  block_8_expand_relu (ReLU)     (None, 10, 14, 384)  0           ['block_8_expand_BN[0][0]']
#
#  block_8_depthwise (DepthwiseCo  (None, 10, 14, 384)  3456       ['block_8_expand_relu[0][0]']
#  nv2D)
#
#  block_8_depthwise_BN (BatchNor  (None, 10, 14, 384)  1536       ['block_8_depthwise[0][0]']
#  malization)
#
#  block_8_depthwise_relu (ReLU)  (None, 10, 14, 384)  0           ['block_8_depthwise_BN[0][0]']
#
#  block_8_project (Conv2D)       (None, 10, 14, 64)   24576       ['block_8_depthwise_relu[0][0]']
#
#  block_8_project_BN (BatchNorma  (None, 10, 14, 64)  256         ['block_8_project[0][0]']
#  lization)
#
#  block_8_add (Add)              (None, 10, 14, 64)   0           ['block_7_add[0][0]',
#                                                                   'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)        (None, 10, 14, 384)  24576       ['block_8_add[0][0]']
#
#  block_9_expand_BN (BatchNormal  (None, 10, 14, 384)  1536       ['block_9_expand[0][0]']
#  ization)
#
#  block_9_expand_relu (ReLU)     (None, 10, 14, 384)  0           ['block_9_expand_BN[0][0]']
#
#  block_9_depthwise (DepthwiseCo  (None, 10, 14, 384)  3456       ['block_9_expand_relu[0][0]']
#  nv2D)
#
#  block_9_depthwise_BN (BatchNor  (None, 10, 14, 384)  1536       ['block_9_depthwise[0][0]']
#  malization)
#
#  block_9_depthwise_relu (ReLU)  (None, 10, 14, 384)  0           ['block_9_depthwise_BN[0][0]']
#
#  block_9_project (Conv2D)       (None, 10, 14, 64)   24576       ['block_9_depthwise_relu[0][0]']
#
#  block_9_project_BN (BatchNorma  (None, 10, 14, 64)  256         ['block_9_project[0][0]']
#  lization)
#
#  block_9_add (Add)              (None, 10, 14, 64)   0           ['block_8_add[0][0]',
#                                                                   'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)       (None, 10, 14, 384)  24576       ['block_9_add[0][0]']
#
#  block_10_expand_BN (BatchNorma  (None, 10, 14, 384)  1536       ['block_10_expand[0][0]']
#  lization)
#
#  block_10_expand_relu (ReLU)    (None, 10, 14, 384)  0           ['block_10_expand_BN[0][0]']
#
#  block_10_depthwise (DepthwiseC  (None, 10, 14, 384)  3456       ['block_10_expand_relu[0][0]']
#  onv2D)
#
#  block_10_depthwise_BN (BatchNo  (None, 10, 14, 384)  1536       ['block_10_depthwise[0][0]']
#  rmalization)
#
#  block_10_depthwise_relu (ReLU)  (None, 10, 14, 384)  0          ['block_10_depthwise_BN[0][0]']
#
#  block_10_project (Conv2D)      (None, 10, 14, 96)   36864       ['block_10_depthwise_relu[0][0]']
#
#  block_10_project_BN (BatchNorm  (None, 10, 14, 96)  384         ['block_10_project[0][0]']
#  alization)
#
#  block_11_expand (Conv2D)       (None, 10, 14, 576)  55296       ['block_10_project_BN[0][0]']
#
#  block_11_expand_BN (BatchNorma  (None, 10, 14, 576)  2304       ['block_11_expand[0][0]']
#  lization)
#
#  block_11_expand_relu (ReLU)    (None, 10, 14, 576)  0           ['block_11_expand_BN[0][0]']
#
#  block_11_depthwise (DepthwiseC  (None, 10, 14, 576)  5184       ['block_11_expand_relu[0][0]']
#  onv2D)
#
#  block_11_depthwise_BN (BatchNo  (None, 10, 14, 576)  2304       ['block_11_depthwise[0][0]']
#  rmalization)
#
#  block_11_depthwise_relu (ReLU)  (None, 10, 14, 576)  0          ['block_11_depthwise_BN[0][0]']
#
#  block_11_project (Conv2D)      (None, 10, 14, 96)   55296       ['block_11_depthwise_relu[0][0]']
#
#  block_11_project_BN (BatchNorm  (None, 10, 14, 96)  384         ['block_11_project[0][0]']
#  alization)
#
#  block_11_add (Add)             (None, 10, 14, 96)   0           ['block_10_project_BN[0][0]',
#                                                                   'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)       (None, 10, 14, 576)  55296       ['block_11_add[0][0]']
#
#  block_12_expand_BN (BatchNorma  (None, 10, 14, 576)  2304       ['block_12_expand[0][0]']
#  lization)
#
#  block_12_expand_relu (ReLU)    (None, 10, 14, 576)  0           ['block_12_expand_BN[0][0]']
#
#  block_12_depthwise (DepthwiseC  (None, 10, 14, 576)  5184       ['block_12_expand_relu[0][0]']
#  onv2D)
#
#  block_12_depthwise_BN (BatchNo  (None, 10, 14, 576)  2304       ['block_12_depthwise[0][0]']
#  rmalization)
#
#  block_12_depthwise_relu (ReLU)  (None, 10, 14, 576)  0          ['block_12_depthwise_BN[0][0]']
#
#  block_12_project (Conv2D)      (None, 10, 14, 96)   55296       ['block_12_depthwise_relu[0][0]']
#
#  block_12_project_BN (BatchNorm  (None, 10, 14, 96)  384         ['block_12_project[0][0]']
#  alization)
#
#  block_12_add (Add)             (None, 10, 14, 96)   0           ['block_11_add[0][0]',
#                                                                   'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)       (None, 10, 14, 576)  55296       ['block_12_add[0][0]']
#
#  block_13_expand_BN (BatchNorma  (None, 10, 14, 576)  2304       ['block_13_expand[0][0]']
#  lization)
#
#  block_13_expand_relu (ReLU)    (None, 10, 14, 576)  0           ['block_13_expand_BN[0][0]']
#
#  block_13_pad (ZeroPadding2D)   (None, 11, 15, 576)  0           ['block_13_expand_relu[0][0]']
#
#  block_13_depthwise (DepthwiseC  (None, 5, 7, 576)   5184        ['block_13_pad[0][0]']
#  onv2D)
#
#  block_13_depthwise_BN (BatchNo  (None, 5, 7, 576)   2304        ['block_13_depthwise[0][0]']
#  rmalization)
#
#  block_13_depthwise_relu (ReLU)  (None, 5, 7, 576)   0           ['block_13_depthwise_BN[0][0]']
#
#  block_13_project (Conv2D)      (None, 5, 7, 160)    92160       ['block_13_depthwise_relu[0][0]']
#
#  block_13_project_BN (BatchNorm  (None, 5, 7, 160)   640         ['block_13_project[0][0]']
#  alization)
#
#  block_14_expand (Conv2D)       (None, 5, 7, 960)    153600      ['block_13_project_BN[0][0]']
#
#  block_14_expand_BN (BatchNorma  (None, 5, 7, 960)   3840        ['block_14_expand[0][0]']
#  lization)
#
#  block_14_expand_relu (ReLU)    (None, 5, 7, 960)    0           ['block_14_expand_BN[0][0]']
#
#  block_14_depthwise (DepthwiseC  (None, 5, 7, 960)   8640        ['block_14_expand_relu[0][0]']
#  onv2D)
#
#  block_14_depthwise_BN (BatchNo  (None, 5, 7, 960)   3840        ['block_14_depthwise[0][0]']
#  rmalization)
#
#  block_14_depthwise_relu (ReLU)  (None, 5, 7, 960)   0           ['block_14_depthwise_BN[0][0]']
#
#  block_14_project (Conv2D)      (None, 5, 7, 160)    153600      ['block_14_depthwise_relu[0][0]']
#
#  block_14_project_BN (BatchNorm  (None, 5, 7, 160)   640         ['block_14_project[0][0]']
#  alization)
#
#  block_14_add (Add)             (None, 5, 7, 160)    0           ['block_13_project_BN[0][0]',
#                                                                   'block_14_project_BN[0][0]']
#
#  block_15_expand (Conv2D)       (None, 5, 7, 960)    153600      ['block_14_add[0][0]']
#
#  block_15_expand_BN (BatchNorma  (None, 5, 7, 960)   3840        ['block_15_expand[0][0]']
#  lization)
#
#  block_15_expand_relu (ReLU)    (None, 5, 7, 960)    0           ['block_15_expand_BN[0][0]']
#
#  block_15_depthwise (DepthwiseC  (None, 5, 7, 960)   8640        ['block_15_expand_relu[0][0]']
#  onv2D)
#
#  block_15_depthwise_BN (BatchNo  (None, 5, 7, 960)   3840        ['block_15_depthwise[0][0]']
#  rmalization)
#
#  block_15_depthwise_relu (ReLU)  (None, 5, 7, 960)   0           ['block_15_depthwise_BN[0][0]']
#
#  block_15_project (Conv2D)      (None, 5, 7, 160)    153600      ['block_15_depthwise_relu[0][0]']
#
#  block_15_project_BN (BatchNorm  (None, 5, 7, 160)   640         ['block_15_project[0][0]']
#  alization)
#
#  block_15_add (Add)             (None, 5, 7, 160)    0           ['block_14_add[0][0]',
#                                                                   'block_15_project_BN[0][0]']
#
#  block_16_expand (Conv2D)       (None, 5, 7, 960)    153600      ['block_15_add[0][0]']
#
#  block_16_expand_BN (BatchNorma  (None, 5, 7, 960)   3840        ['block_16_expand[0][0]']
#  lization)
#
#  block_16_expand_relu (ReLU)    (None, 5, 7, 960)    0           ['block_16_expand_BN[0][0]']
#
#  block_16_depthwise (DepthwiseC  (None, 5, 7, 960)   8640        ['block_16_expand_relu[0][0]']
#  onv2D)
#
#  block_16_depthwise_BN (BatchNo  (None, 5, 7, 960)   3840        ['block_16_depthwise[0][0]']
#  rmalization)
#
#  block_16_depthwise_relu (ReLU)  (None, 5, 7, 960)   0           ['block_16_depthwise_BN[0][0]']
#
#  block_16_project (Conv2D)      (None, 5, 7, 320)    307200      ['block_16_depthwise_relu[0][0]']
#
#  block_16_project_BN (BatchNorm  (None, 5, 7, 320)   1280        ['block_16_project[0][0]']
#  alization)
#
#  Conv_1 (Conv2D)                (None, 5, 7, 1280)   409600      ['block_16_project_BN[0][0]']
#
#  Conv_1_bn (BatchNormalization)  (None, 5, 7, 1280)  5120        ['Conv_1[0][0]']
#
#  out_relu (ReLU)                (None, 5, 7, 1280)   0           ['Conv_1_bn[0][0]']
#
# ==================================================================================================
# Total params: 2,257,984
# Trainable params: 2,223,872
# Non-trainable params: 34,112
# __________________________________________________________________________________________________
# No. of MobileNetV2 model layers: 154

# %%
# Print out the overall model summary
mob_netv2.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenetv2_1.00_224 (Funct  (None, 5, 7, 1280)       2257984
#  ional)
#
#  global_average_pooling2d_4   (None, 1280)             0
#  (GlobalAveragePooling2D)
#
#  dropout_4 (Dropout)         (None, 1280)              0
#
#  dense_16 (Dense)            (None, 256)               327936
#
#  dense_17 (Dense)            (None, 64)                16448
#
#  dense_18 (Dense)            (None, 16)                1040
#
#  dense_19 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 2,603,425
# Trainable params: 345,441
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
# compiling process
mob_netv2.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
hist_mobnetv2 = mob_netv2.fit(X_train, Y_train, epochs=10, batch_size=32, validation_data = (X_test, Y_test))
# Out:
# Epoch 1/10
# 18/18 [==============================] - 5s 176ms/step - loss: 0.1898 - accuracy: 0.9208 - val_loss: 0.0106 - val_accuracy: 1.0000
# Epoch 2/10
# 18/18 [==============================] - 3s 151ms/step - loss: 0.0171 - accuracy: 0.9912 - val_loss: 0.0191 - val_accuracy: 0.9930
# Epoch 3/10
# 18/18 [==============================] - 3s 155ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.0113 - val_accuracy: 1.0000
# Epoch 4/10
# 18/18 [==============================] - 3s 152ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0987 - val_accuracy: 0.9720
# Epoch 5/10
# 18/18 [==============================] - 3s 152ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.0123 - val_accuracy: 0.9930
# Epoch 6/10
# 18/18 [==============================] - 3s 152ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0037 - val_accuracy: 1.0000
# Epoch 7/10
# 18/18 [==============================] - 3s 154ms/step - loss: 0.0045 - accuracy: 0.9982 - val_loss: 0.0415 - val_accuracy: 0.9860
# Epoch 8/10
# 18/18 [==============================] - 3s 156ms/step - loss: 7.2661e-04 - accuracy: 1.0000 - val_loss: 0.0133 - val_accuracy: 0.9930
# Epoch 9/10
# 18/18 [==============================] - 3s 159ms/step - loss: 2.2858e-04 - accuracy: 1.0000 - val_loss: 0.0151 - val_accuracy: 0.9930
# Epoch 10/10
# 18/18 [==============================] - 3s 159ms/step - loss: 1.4157e-04 - accuracy: 1.0000 - val_loss: 0.0208 - val_accuracy: 0.9930

# %%
# The history.history["loss"] entry is a dictionary with as many values as epochs that the
# model was trained on. 

df_loss_acc = pd.DataFrame(hist_mobnetv2.history)

# losses data frame
df_loss= df_loss_acc[['loss','val_loss']]
df_loss.rename(columns={'loss':'train','val_loss':'validation'},inplace=True)

# accuracy data frame
df_acc= df_loss_acc[['accuracy','val_accuracy']]
df_acc.rename(columns={'accuracy':'train','val_accuracy':'validation'},inplace=True)

# plotting the loss and accuracy
df_loss.plot(title='Model loss',figsize=(8,6)).set(xlabel='Epoch',ylabel='Loss')
df_acc.plot(title='Model Accuracy',figsize=(8,6)).set(xlabel='Epoch',ylabel='Accuracy')
# Out:
# /var/folders/c8/g5hp4hlx7dv6gv7n9zdg74rc0000gn/T/ipykernel_24336/1284852736.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_loss.rename(columns={'loss':'train','val_loss':'validation'},inplace=True)
# /var/folders/c8/g5hp4hlx7dv6gv7n9zdg74rc0000gn/T/ipykernel_24336/1284852736.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_acc.rename(columns={'accuracy':'train','val_accuracy':'validation'},inplace=True)
# [Text(0.5, 0, 'Epoch'), Text(0, 0.5, 'Accuracy')]

# %%
ypred_train_mob = mob_netv2.predict(X_train)
ypred_train_mob[ypred_train_mob > 0.5] = 1
ypred_train_mob[ypred_train_mob < 0.5] = 0

ypred_test_mob = mob_netv2.predict(X_test)
ypred_test_mob[ypred_test_mob > 0.5] = 1
ypred_test_mob[ypred_test_mob < 0.5] = 0

print("Training data:")
print(f" Precision : {precision_score(Y_train, ypred_train_mob)}, Recall: {recall_score(Y_train, ypred_train_mob)},F1-score:{f1_score(Y_train, ypred_train_mob)}")

print("Test data:")
print(f" Precision : {precision_score(Y_test, ypred_test_mob)}, Recall: {recall_score(Y_test, ypred_test_mob)}, F1-score:{f1_score(Y_test, ypred_test_mob)}")
# Out:
# 18/18 [==============================] - 2s 123ms/step
# 5/5 [==============================] - 1s 116ms/step
# Training data:
#  Precision : 1.0, Recall: 1.0,F1-score:1.0
# Test data:
#  Precision : 1.0, Recall: 0.9827586206896551, F1-score:0.9913043478260869

# %%
# Confusion matrix from the test data
ConfusionMatrixDisplay.from_predictions(Y_test, ypred_test_mob, display_labels = ['Paved','Unpaved'])
plt.show()

# %%
print(classification_report(Y_test, ypred_test_mob, target_names=['Paved', 'Unpaved']))
# Out:
#               precision    recall  f1-score   support
#
#        Paved       0.99      1.00      0.99        85
#      Unpaved       1.00      0.98      0.99        58
#
#     accuracy                           0.99       143
#    macro avg       0.99      0.99      0.99       143
# weighted avg       0.99      0.99      0.99       143

# %%
# Let's visualize some of the results from our modeling efforts
fig, axs = plt.subplots(4, 5, figsize=(12,10), tight_layout = True)
axs = axs.flatten()
for i in range(len(axs)):
    axs[i].imshow(X_test[i, :, :, :])
    axs[i].set_title(f"Cat:{ypred_test_mob[i]}")
    axs[i].axis("off")
plt.show()

# %% [markdown]
# The models results looks really good by using the image nets. Since we are getting very accurate results with the pretrained imagenet weights, further fine tuning of the outer layers is not necessary.
